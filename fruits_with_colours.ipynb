# %% [markdown]
# <a href="https://colab.research.google.com/github/rhutuja-desai/classification-of-fruits-by-colour/blob/main/fruits_with_colours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_table('fruit_data_with_colors.txt')
ac=pd.DataFrame(df)
ac
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
dcat = ac.select_dtypes(include=[object])
dcat.head()
# Out:
#   fruit_name fruit_subtype
# 0      apple  granny_smith
# 1      apple  granny_smith
# 2      apple  granny_smith
# 3   mandarin      mandarin
# 4   mandarin      mandarin

# %%
dcat.shape
# Out:
# (59, 2)

# %%
x = ac.iloc[:,[3,4,5]].values
y = ac.iloc[:,1].values
print(x,y)
# Out:
# [[192.    8.4   7.3]
#  [180.    8.    6.8]
#  [176.    7.4   7.2]
#  [ 86.    6.2   4.7]
#  [ 84.    6.    4.6]
#  [ 80.    5.8   4.3]
#  [ 80.    5.9   4.3]
#  [ 76.    5.8   4. ]
#  [178.    7.1   7.8]
#  [172.    7.4   7. ]
#  [166.    6.9   7.3]
#  [172.    7.1   7.6]
#  [154.    7.    7.1]
#  [164.    7.3   7.7]
#  [152.    7.6   7.3]
#  [156.    7.7   7.1]
#  [156.    7.6   7.5]
#  [168.    7.5   7.6]
#  [162.    7.5   7.1]
#  [162.    7.4   7.2]
#  [160.    7.5   7.5]
#  [156.    7.4   7.4]
#  [140.    7.3   7.1]
#  [170.    7.6   7.9]
#  [342.    9.    9.4]
#  [356.    9.2   9.2]
#  [362.    9.6   9.2]
#  [204.    7.5   9.2]
#  [140.    6.7   7.1]
#  [160.    7.    7.4]
#  [158.    7.1   7.5]
#  [210.    7.8   8. ]
#  [164.    7.2   7. ]
#  [190.    7.5   8.1]
#  [142.    7.6   7.8]
#  [150.    7.1   7.9]
#  [160.    7.1   7.6]
#  [154.    7.3   7.3]
#  [158.    7.2   7.8]
#  [144.    6.8   7.4]
#  [154.    7.1   7.5]
#  [180.    7.6   8.2]
#  [154.    7.2   7.2]
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 1)

# %%
from sklearn.preprocessing import MinMaxScaler 
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train) 
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[0.31468531, 0.28947368, 0.52380952],
#        [0.13986014, 0.05263158, 0.55555556],
#        [1.        , 1.        , 0.82539683],
#        [0.13986014, 0.13157895, 0.58730159],
#        [0.28671329, 0.34210526, 0.55555556],
#        [0.36363636, 0.47368421, 0.66666667],
#        [0.34265734, 0.39473684, 0.96825397],
#        [0.44755245, 0.44736842, 0.82539683],
#        [0.48951049, 0.39473684, 0.98412698],
#        [0.26573427, 0.18421053, 0.71428571],
#        [0.46853147, 0.52631579, 0.63492063],
#        [0.30769231, 0.39473684, 0.58730159],
#        [0.22377622, 0.39473684, 0.49206349],
#        [0.18881119, 0.05263158, 0.66666667],
#        [0.30769231, 0.36842105, 0.47619048],
#        [0.32167832, 0.44736842, 0.57142857],
#        [0.13986014, 0.07894737, 0.71428571],
#        [0.3986014 , 0.44736842, 0.65079365],
#        [0.32867133, 0.47368421, 0.61904762],
#        [0.02797203, 0.05263158, 0.0952381 ],
#        [0.26573427, 0.47368421, 0.52380952],
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors = 5,metric = 'euclidean')

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array(['lemon', 'apple', 'apple', 'lemon', 'orange', 'apple', 'apple',
#        'apple', 'apple', 'lemon', 'lemon', 'mandarin', 'apple', 'orange',
#        'orange'], dtype=object)

# %%
y_test
# Out:
# array(['lemon', 'apple', 'orange', 'lemon', 'orange', 'orange', 'orange',
#        'apple', 'apple', 'lemon', 'lemon', 'mandarin', 'orange', 'orange',
#        'orange'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
acc_knn=accuracy_score(y_test,y_pred)*100
acc_knn
# Out:
# 73.33333333333333

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[3, 0, 0, 0],
#        [0, 4, 0, 0],
#        [0, 0, 1, 0],
#        [4, 0, 0, 3]])

# %%
from sklearn.model_selection import train_test_split

x1 = ac.iloc[:,[3,4,5]].values
y1 = ac.iloc[:,1].values



# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(x1, y1, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

from sklearn import metrics
acc_rfc=(metrics.accuracy_score(y_test, y_pred))*100
print("Accuracy:",acc_rfc)
# Out:
# Accuracy: 91.66666666666666

# %%
estimators = np.arange(10, 100, 10)
accuracy = []

for n in estimators:
    clf.set_params(n_estimators=n)
    clf.fit(X_train, y_train)
    y_pred=clf.predict(X_test)
    accuracy.append(metrics.accuracy_score(y_test, y_pred))
plt.title("Effect of n_estimators")
plt.xlabel("n_estimator")
plt.ylabel("accuracy")
plt.plot(estimators, accuracy);

# %%
a = plt.subplot(211)
a.scatter(df['width'],df['height'])
a.set_title('width vs height')
a = plt.subplot(212)
a.scatter(df['width'],df['color_score'])
a.set_title('width vs colorscore')
plt.show()

# %%
data={'accuracy': [acc_knn, acc_rfc],'model': ['K-NN', 'RandomForestClassifer']}
acc_df = pd.DataFrame(data, columns = ['accuracy', 'model'])
acc_df.head()
# Out:
#     accuracy                  model
# 0  73.333333                   K-NN
# 1  91.666667  RandomForestClassifer

# %%
import seaborn as sns


plt.figure(figsize = (10,7))
sns.barplot(y = acc_df.accuracy, x = acc_df.model)
